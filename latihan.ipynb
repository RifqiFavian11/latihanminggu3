# %%
pip install "fastapi[standard]"
# Out:
# Collecting fastapi[standard]
#   Downloading fastapi-0.116.0-py3-none-any.whl.metadata (28 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi[standard])
#   Using cached starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from fastapi[standard]) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\anaconda3\lib\site-packages (from fastapi[standard]) (4.14.1)
# Collecting fastapi-cli>=0.0.8 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading fastapi_cli-0.0.8-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: httpx>=0.23.0 in c:\users\user\anaconda3\lib\site-packages (from fastapi[standard]) (0.27.0)
# Collecting jinja2>=3.1.5 (from fastapi[standard])
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting python-multipart>=0.0.18 (from fastapi[standard])
#   Using cached python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Collecting email-validator>=2.0.0 (from fastapi[standard])
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Collecting uvicorn>=0.12.0 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi[standard]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi[standard]) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\user\anaconda3\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi[standard]) (4.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi[standard]) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi[standard]) (1.3.0)
# Collecting dnspython>=2.0.0 (from email-validator>=2.0.0->fastapi[standard])
#   Using cached dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting typer>=0.15.1 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading typer-0.16.0-py3-none-any.whl.metadata (15 kB)
# Collecting rich-toolkit>=0.14.8 (from fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading rich_toolkit-0.14.8-py3-none-any.whl.metadata (999 bytes)
# Collecting fastapi-cloud-cli>=0.1.1 (from fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading fastapi_cloud_cli-0.1.1-py3-none-any.whl.metadata (3.2 kB)
# Collecting rignore>=0.5.1 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading rignore-0.5.1-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Collecting sentry-sdk>=2.20.0 (from fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading sentry_sdk-2.32.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: certifi in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.23.0->fastapi[standard]) (2025.6.15)
# Requirement already satisfied: httpcore==1.* in c:\users\user\anaconda3\lib\site-packages (from httpx>=0.23.0->fastapi[standard]) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\user\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.23.0->fastapi[standard]) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2>=3.1.5->fastapi[standard]) (2.1.3)
# Requirement already satisfied: click>=8.1.7 in c:\users\user\anaconda3\lib\site-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (8.1.7)
# Requirement already satisfied: rich>=13.7.1 in c:\users\user\anaconda3\lib\site-packages (from rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (13.7.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click>=8.1.7->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\user\anaconda3\lib\site-packages (from rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\user\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->rich-toolkit>=0.14.8->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (0.1.0)
# Requirement already satisfied: urllib3>=1.26.11 in c:\users\user\anaconda3\lib\site-packages (from sentry-sdk>=2.20.0->fastapi-cloud-cli>=0.1.1->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard]) (2.4.0)
# Collecting shellingham>=1.3.0 (from typer>=0.15.1->fastapi-cli>=0.0.8->fastapi-cli[standard]>=0.0.8; extra == "standard"->fastapi[standard])
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading httptools-0.6.4-cp312-cp312-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\user\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]) (0.21.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\anaconda3\lib\site-packages (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard]) (6.0.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading watchfiles-1.1.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.12.0; extra == "standard"->fastapi[standard])
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Downloading fastapi-0.116.0-py3-none-any.whl (95 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Using cached dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading fastapi_cli-0.0.8-py3-none-any.whl (10 kB)
# Downloading fastapi_cloud_cli-0.1.1-py3-none-any.whl (18 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading rich_toolkit-0.14.8-py3-none-any.whl (24 kB)
# Downloading rignore-0.5.1-cp312-cp312-win_amd64.whl (728 kB)
#    ---------------------------------------- 0.0/728.0 kB ? eta -:--:--
#    ---------------------------------------- 728.0/728.0 kB 7.5 MB/s eta 0:00:00
# Downloading sentry_sdk-2.32.0-py2.py3-none-any.whl (356 kB)
# Downloading typer-0.16.0-py3-none-any.whl (46 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading httptools-0.6.4-cp312-cp312-win_amd64.whl (88 kB)
# Downloading watchfiles-1.1.0-cp312-cp312-win_amd64.whl (292 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Installing collected packages: websockets, shellingham, sentry-sdk, rignore, python-multipart, jinja2, httptools, dnspython, watchfiles, uvicorn, starlette, email-validator, typer, rich-toolkit, fastapi, fastapi-cloud-cli, fastapi-cli
#
#    ----------------------------------------  0/17 [websockets]
#    ----------------------------------------  0/17 [websockets]
#    ---- -----------------------------------  2/17 [sentry-sdk]
#    ---- -----------------------------------  2/17 [sentry-sdk]
#    ---- -----------------------------------  2/17 [sentry-sdk]
#    ---- -----------------------------------  2/17 [sentry-sdk]
#    ---- -----------------------------------  2/17 [sentry-sdk]
#    ---- -----------------------------------  2/17 [sentry-sdk]
#    ---- -----------------------------------  2/17 [sentry-sdk]
#    ------- --------------------------------  3/17 [rignore]
#   Attempting uninstall: jinja2
#    ------- --------------------------------  3/17 [rignore]
#     Found existing installation: Jinja2 3.1.4
#    ------- --------------------------------  3/17 [rignore]
#     Uninstalling Jinja2-3.1.4:
#    ------- --------------------------------  3/17 [rignore]
#       Successfully uninstalled Jinja2-3.1.4
#    ------- --------------------------------  3/17 [rignore]
#    ----------- ----------------------------  5/17 [jinja2]
#    ----------- ----------------------------  5/17 [jinja2]
#    -------------- -------------------------  6/17 [httptools]
#    ---------------- -----------------------  7/17 [dnspython]
#    ---------------- -----------------------  7/17 [dnspython]
#    ---------------- -----------------------  7/17 [dnspython]
#    ---------------- -----------------------  7/17 [dnspython]
#    ---------------- -----------------------  7/17 [dnspython]
#    ---------------- -----------------------  7/17 [dnspython]
#    --------------------- ------------------  9/17 [uvicorn]
#    --------------------- ------------------  9/17 [uvicorn]
#    ----------------------- ---------------- 10/17 [starlette]
#    ----------------------- ---------------- 10/17 [starlette]
#    ---------------------------- ----------- 12/17 [typer]
#    ------------------------------ --------- 13/17 [rich-toolkit]
#    -------------------------------- ------- 14/17 [fastapi]
#    -------------------------------- ------- 14/17 [fastapi]
#    ------------------------------------- -- 16/17 [fastapi-cli]
#    ---------------------------------------- 17/17 [fastapi-cli]
#
# Successfully installed dnspython-2.7.0 email-validator-2.2.0 fastapi-0.116.0 fastapi-cli-0.0.8 fastapi-cloud-cli-0.1.1 httptools-0.6.4 jinja2-3.1.6 python-multipart-0.0.20 rich-toolkit-0.14.8 rignore-0.5.1 sentry-sdk-2.32.0 shellingham-1.5.4 starlette-0.46.2 typer-0.16.0 uvicorn-0.35.0 watchfiles-1.1.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install fastapi uvicorn
# Out:
# Requirement already satisfied: fastapi in c:\users\user\anaconda3\lib\site-packages (0.116.0)
# Requirement already satisfied: uvicorn in c:\users\user\anaconda3\lib\site-packages (0.35.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in c:\users\user\anaconda3\lib\site-packages (from fastapi) (0.46.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in c:\users\user\anaconda3\lib\site-packages (from fastapi) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\user\anaconda3\lib\site-packages (from fastapi) (4.14.1)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\user\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi) (2.20.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\user\anaconda3\lib\site-packages (from starlette<0.47.0,>=0.40.0->fastapi) (4.2.0)
# Requirement already satisfied: idna>=2.8 in c:\users\user\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (3.7)
# Requirement already satisfied: sniffio>=1.1 in c:\users\user\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi) (1.3.0)
# Requirement already satisfied: click>=7.0 in c:\users\user\anaconda3\lib\site-packages (from uvicorn) (8.1.7)
# Requirement already satisfied: h11>=0.8 in c:\users\user\anaconda3\lib\site-packages (from uvicorn) (0.14.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from click>=7.0->uvicorn) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
from fastapi import FastAPI

app = FastAPI()

@app.get("/")
async def read_root():
    return {"message": "Hello, FastAPI!"}
